# %%
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
from utils.err import *

# %%
from utils.vis import plotCSV

# %%
csv_data = '../dataGeneration/csv/Au_updated.csv'

# %%
plotCSV(
    csv_data, 
    debug=True, scatter=True, continuous=True,
    cols=['n', 'k', 'er', 'ei']
)

# %%
# plotCSV(
#     csv_data, 
#     debug=True, scatter=False, continuous=True,
#     cols=['n', 'k']
# )

# %%
csv_data = '../dataGeneration/csv/Au_interpolated.csv'
plotCSV(
    csv_data, 
    debug=True, scatter=False, continuous=True,
    cols=['n', 'k', 'er', 'ei']
)
